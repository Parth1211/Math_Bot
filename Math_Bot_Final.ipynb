# %%
def error_analysis(str):                            # function for error analysis in the equation
    n=len(str)
    pos=-1
    f1=0
    for i in range(1,n):                             # to check error of repeated operation
        if str[i]=='=' and str[i-1]==str[i]:
            pos=i
            break
        if str[i]=='+' and str[i-1]==str[i]:
            pos=i
            break
        if str[i]=='*' and str[i-1]==str[i]:
            pos=i
            break
        if str[i]=='-' and str[i-1]==str[i]:
            pos=i
            break
        if str[i]=='/' and str[i-1]==str[i]:
            pos=i
            break
        if str[i]=='^' and str[i-1]==str[i]:
            pos=i
            break
        if str[i]=='<' and str[i-1]==str[i]:
            pos=i
            break
        if str[i]=='>' and str[i-1]==str[i]:
            pos=i
            break
        if str[i]!='x' and str[i]!='y' and str[i]!='(' and str[i]!=')' and str[i]!='=' and str[i]!='+' and str[i]!='-' and str[i]!='*' and str[i]!='/' and str[i]!='^' and str[i]!='>' and str[i]!='<' and str[i]!='D' and str[i]!='I' and str[i]!='S' and (ord(str[i])>57 or ord(str[i])<48):
            pos=i                 
            f1=1                                    # to check if there is any typo, unnecessary term
            break
          
    c1=c2=c3=0
    for i in range(1,n):                            # to check if there are more than 1 comparison operater
        if str[i]=='=':
            c1+=1
        if str[i]=='>':
            c2+=1
        if str[i]=='<':
            c3+=1
        
        if c1+c2+c3>1:
            pos=i
            break
        
    flag=1    
    if str[0]=='=' or str[0]=='>' or str[0]=='<':            #  \
        pos=0                                                #   \
                                                             #    --> As an equation can't start or end with these operators.
    if str[-1]=='=' or str[-1]=='>' or str[-1]=='<':         #  /
        pos=n-1                                              # /
        
        
    if pos!=-1:
        print('\n',str)
        x='.'
        print(x*pos,'^ This might lead to an error!!!')     # to indicate the position of the error in the equation
        
    count=0
    for i in range(0,n):
        if str[i]=='=' or str[i]=='>' or str[i]=='<':
            count+=1
    if count>1:
        print("CAUTION: The given equation has more than 1 comparison operator(=,> or <)")

# %%
def symb_identifier(str):               # function to identify all the terms in the equation
    n=len(str)
    print('\n')
    for i in range(n):
        if ord(str[i])<=57 and ord(str[i])>=48:
            p1=i
            break
    f=1
    f1=0                         ## to check if inequality or or not
    f2=0
    i=p1+1
    ##print(p1,'\n')
    for i in range(p1+1,n):
        if f==1 and (ord(str[i])<=57 and ord(str[i])>=48):
            continue
        elif f==1 and (ord(str[i])>57 or ord(str[i])<48):
            ##sub = str(p1, i-p1)
            sub = str[p1:][:i-p1]                ## used to print more than single digit number in 1 go, rather than only digits
            print(int(sub),': number')
            if str[i]=='(':
                print("(: bracket open")
            elif str[i]==')':
                print("): bracket close")
            elif str[i]=='x' or str[i]=='y':
                print(str[i],": variable")
            elif str[i]=='-':
                print("-: subtraction/minus")
            elif str[i]=='+':
                print("+: addition/plus")
            elif str[i]=='=':
                print("=: equal to")
                f2=1
            elif str[i]=='>':
                print(" >: greater than")
                f1=1
            elif str[i]=='<':
                print(" <: less than")
                f1=1
            elif str[i]=='*':
                print("*: multiplication/product") 
            elif str[i]=='^':
                print("^: raised to the power")
            else:
                print(s[i],": variable(my guess!)")
            f=0
            
        elif f==0 and (ord(str[i])>57 or ord(str[i])<48):
            if str[i]=='(':
                print("(: bracket open")
            elif str[i]==')':
                print("): bracket close")
            elif str[i]=='x' or str[i]=='y':
                print(str[i],": variable")
            elif str[i]=='-':
                print("-: subtraction/minus")
            elif str[i]=='+':
                print("+: addition/plus")
            elif str[i]=='=':
                print("=: equal to")
                f2=1
            elif str[i]=='>':
                print(">: greater than")
                f1=1
            elif str[i]=='<':
                print("<: less than")
                f1=1
            elif str[i]=='*':
                print("*: multiplication/product")
            elif str[i]=='^':
                print("^: raised to the power")
            else:
                print(s[i],": variable(my guess!)")
                
            
            
        elif f==0 and (ord(str[i])<=57 and ord(str[i])>=48):
            p1=i
            f=1
            
    if f==1:
        sub = str[p1:][:i-p1+1]                  ## used to print more than single digit number in 1 go, rather than only digits      
        print(int(sub),': number')
        f=0
        
    
    if f1==1:
        print("\nThis is an inequality(if there is no caution)")
    elif f2==1:
        print("\nThis is an equation(if there is no caution)")

# %%
def degree_finder(str):            # to find the degree of the equation, taking x and y as the variables
    deg=0
    for i in range(1,len(str)):
        if (str[i-1]=='x' or str[i-1]=='y') and str[i]=='^':
            deg = max(deg,ord(str[i+1])-ord('0'))
    print('\nThe degree of this equation(x,y are taken to be the variables) is ',deg)

# %%
print('Hello friends, I am your math bot, analyzing and helping you in what you type onto me!.')

while True:                         # this loop will keep on running until the user wants to exit
    print("------------------------------------------------------------------------------------")
    print('Press I for integral\n      D for derivative\n      N for a normal equation')    
    t=input("\nWhat type of equation is it?")

    s=input("\nType the equation-\n")    # equation taken in the form of a string
    if t=='I':
        print('\nWe have to integrate the given expression.\n I : Integral of\n',s)
    if t=='D':
        print('\nWe have to differentiate the given expression.\n D : Derivative of\n',s)
    if t=='N':
        print('\nThe given equation is-\n',s)
    
    symb_identifier(s)  #\
    degree_finder(s)    # > all the functions called
    error_analysis(s)   #/
    
    f=input('\nDo you want to continue typing more equations?\nIf yes, then press Y, else press N.\n')
    if f!='Y' and f!='N':
        f=input('\nSorry, that was a wrong command, press Y(to continue) or N(not to continue).\n')
    if f=='Y':
        continue
    elif f=='N':
        print('\nIt was nice helping you, hope that a much more improved, advanced version of me gets to action at region infinity :)')
        break
# Out:
# Hello friends, I am your math bot, analyzing and helping you in what you type onto me!.
# ------------------------------------------------------------------------------------
# Press I for integral
#       D for derivative
#       N for a normal equation
#
# What type of equation is it?N
#
# Type the equation-
# 257+314-25*2=521
#
# The given equation is-
#  257+314-25*2=521
#
#
# 257 : number
# +: addition/plus
# 314 : number
# -: subtraction/minus
# 25 : number
# *: multiplication/product
# 2 : number
# =: equal to
# 521 : number
#
# This is an equation(if there is no caution)
#
# The degree of this equation(x,y are taken to be the variables) is  0
#
# Do you want to continue typing more equations?
# If yes, then press Y, else press N.
# Y
# ------------------------------------------------------------------------------------
# Press I for integral
#       D for derivative
#       N for a normal equation
#
# What type of equation is it?N
#
# Type the equation-
# 23+95**6=593
#
# ...

# %%
"""""
I would request you to go through all of my test cases, which cover the different types of cases my bot 
can handle and comment on, I have also added comments to my code to make it more readable, understandable.

One of the special attribute of my code is, to detect the whole number, rather than just bit by bit analysis
        for example- 
        12-3=9,
        will not be shown as-
        1: number
        2: number
        -: minus/subtraction
        3: number
        =: minus/subtraction
        9: number
        
        instead it will be shown as-
        12: number
        -: minus/subtraction
        3: number
        =: equals
        9: number

And does also do some other special things like-
* error analysis, the location there might be an error on and pointing to it
* telling the degree of the polynomial 
* telling if there might be a typoin the string

Hope my attempt impresses you, as I am really looking forward to work more in this area along with experts 
like you. My bot may have not covered all the possible cases(as I got it ready in only 24hrs though), but
can surely show you my perfect experience with programming along with the new ideas I can get to help you with my efforts

Thanking you(hoping to get into work with you soon!)
Parth Bhardwaj
8826730317
parthb@iitk.ac.in , parth.bhardwaj1211@gmail.com
        
""""
